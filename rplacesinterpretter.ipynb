# %%
import pandas as pd

assets = pd.read_csv("relevantplaces.csv", dtype='string')
assets.head(10)
# Out:
#                                            name                asset_type  \
# 0                              SWEETBRIAR PLACE        affordable_housing
# 1                             SUSQUEHANNA HOMES        affordable_housing
# 2                                 STO-ROX PLAZA        affordable_housing
# 3                         American Serbian Club  community_nonprofit_orgs
# 4      Community Kitchen Pittsburgh (Hazelwood)  community_nonprofit_orgs
# 5                            STEELWORKERS TOWER        affordable_housing
# 6                               ST JUSTIN PLAZA        affordable_housing
# 7                                  MARIAN PLAZA        affordable_housing
# 8  Riverview Church, on Pittsburgh's North Side  community_nonprofit_orgs
# 9      Armstrong Playground (Play Area 5 to 12)      parks_and_facilities
#
#        neighborhood
# 0  Duquesne Heights
# 1    Homewood South
# 2           Elliott
# 3  South Side Flats
# 4         Hazelwood
# 5       Perry South
# ...
